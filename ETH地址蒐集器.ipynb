# %% [markdown]
# <a href="https://colab.research.google.com/github/hibana2077/Fail-Side-Projects/blob/main/ETH%E5%9C%B0%E5%9D%80%E8%92%90%E9%9B%86%E5%99%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install web3
# Out:
# ...
#      |████████████████████████████████| 500 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 5.8 MB/s
# ...
#      |████████████████████████████████| 103 kB 56.4 MB/s
# ...
#      |████████████████████████████████| 82 kB 345 kB/s
# ...
#      |████████████████████████████████| 101 kB 10.6 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 271 kB 69.4 MB/s
# ...
#      |████████████████████████████████| 144 kB 54.8 MB/s
# ...
#      |████████████████████████████████| 45 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 48 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 2.0 MB 45.1 MB/s
# ...
#      |████████████████████████████████| 481 kB 50.8 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 41.9 MB/s
# ...
#   Created wheel for bitarray: filename=bitarray-1.2.2-cp37-cp37m-linux_x86_64.whl size=107017 sha256=247b7f98e224d56d48e9a01820ffe20570987fe885abea5d37ffecb91ae39f11
# ...

# %%
# !lscpu
# Out:
# Architecture:        x86_64
# CPU op-mode(s):      32-bit, 64-bit
# Byte Order:          Little Endian
# CPU(s):              2
# On-line CPU(s) list: 0,1
# Thread(s) per core:  2
# Core(s) per socket:  1
# Socket(s):           1
# NUMA node(s):        1
# Vendor ID:           GenuineIntel
# CPU family:          6
# Model:               79
# Model name:          Intel(R) Xeon(R) CPU @ 2.20GHz
# Stepping:            0
# CPU MHz:             2199.998
# BogoMIPS:            4399.99
# Hypervisor vendor:   KVM
# Virtualization type: full
# L1d cache:           32K
# L1i cache:           32K
# L2 cache:            256K
# L3 cache:            56320K
# NUMA node0 CPU(s):   0,1
# ...

# %%
#匯入
from web3 import Web3
import json
from timeit import default_timer as timer

#連線
w3=Web3(Web3.HTTPProvider('https://eth-mainnet.alchemyapi.io/v2/r5LWV9YohEw08-xtCrMjWcWy0q64_KJq'))
if w3.isConnected():print("Connected !")
else :print("Error !")

#constant
FILE='ETH_active_address.json'
START=930001

#資料寫入
datatojson=json.load(open('ETH_active_address.json','r'))


#每次啟動就更新
nownum=w3.eth.get_block_number()
startt=timer()
#讀取資料
for a in range(START,nownum):
    
    print(f"目前進度:{((a-START)/(nownum-START))*10000:.4f} % 使用時間:{timer()-startt:.2f}s")
    startt=timer()
    for b in range(w3.eth.get_block_transaction_count(START)):
        tempdata=dict(w3.eth.get_transaction_by_block(START,b))
        if tempdata['from'] in datatojson:pass
        else:datatojson.append(tempdata['from'])
        if tempdata['to'] in datatojson:pass
        else:datatojson.append(tempdata['to'])
#寫入
file = open('python\ETH\ETH_active_address.json','w')
json.dump(datatojson,file)
file.close()
# Out:
# Connected !
# 目前進度:0.0000 % 使用時間:0.00s
# 目前進度:1.2762 % 使用時間:22.36s
# 目前進度:2.5523 % 使用時間:19.81s
# 目前進度:3.8285 % 使用時間:19.57s
# 目前進度:5.1046 % 使用時間:20.12s
# 目前進度:6.3808 % 使用時間:21.08s
# 目前進度:7.6570 % 使用時間:19.17s
# 目前進度:8.9331 % 使用時間:20.52s
# 目前進度:10.2093 % 使用時間:19.93s
# 目前進度:11.4855 % 使用時間:19.30s
# 目前進度:12.7616 % 使用時間:19.38s
# 目前進度:14.0378 % 使用時間:23.06s
# 目前進度:15.3139 % 使用時間:19.41s
# 目前進度:16.5901 % 使用時間:19.84s
# 目前進度:17.8663 % 使用時間:20.29s
# 目前進度:19.1424 % 使用時間:19.07s
# 目前進度:20.4186 % 使用時間:19.24s
# 目前進度:21.6947 % 使用時間:20.68s
# 目前進度:22.9709 % 使用時間:19.15s
# 目前進度:24.2471 % 使用時間:19.18s
# 目前進度:25.5232 % 使用時間:19.87s
# 目前進度:26.7994 % 使用時間:19.79s
# 目前進度:28.0755 % 使用時間:18.88s
# 目前進度:29.3517 % 使用時間:19.59s
# 目前進度:30.6279 % 使用時間:19.30s
# 目前進度:31.9040 % 使用時間:19.02s
# 目前進度:33.1802 % 使用時間:19.11s
# 目前進度:34.4564 % 使用時間:19.46s
# 目前進度:35.7325 % 使用時間:19.03s
# 目前進度:37.0087 % 使用時間:19.51s
# 目前進度:38.2848 % 使用時間:19.09s
# 目前進度:39.5610 % 使用時間:19.90s
# 目前進度:40.8372 % 使用時間:19.62s
# 目前進度:42.1133 % 使用時間:20.04s
# ...
